# %% [markdown]
# <a href="https://colab.research.google.com/github/dmribeiro1/DRibeiroAssignment9/blob/main/CapstoneProject_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
# Create a DataFrame with the provided data
data = {
    'Year': [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020] * 3,
    'Country': ['Hong Kong'] * 21 + ['India'] * 21 + ['United States'] * 21,
    'Total Red meat consumed in kgs per capita': [
        70.14531433, 70.8399659, 68.56647245, 72.3551376, 79.0422852, 77.8897127, 83.1730689, 82.2914734, 83.7957905, 85.4121947,
        66.9894391, 68.0644875, 77.0838158, 73.4274147, 74.4634309, 77.2608296, 80.9551505, 83.0424437, 81.7943729, 75.39197774,
        80.7471877,  # Red meat consumption data for Hong Kong
        3.05901455, 3.06369999, 2.96058761, 2.88762105, 2.90298509, 2.7821347, 2.73053629, 2.73773172, 2.7061126, 2.58717161,
        2.33800452, 2.047988, 1.83736102, 1.63684983, 1.7542318, 1.8322195, 1.77112029, 1.70028898, 1.9069346, 1.87706668,
        1.95677027,  # Red meat consumption data for India
        74.8776286, 73.73893517, 75.57986215, 73.9678193, 74.28694286, 73.00401356, 72.85807895, 73.0509517, 71.2234512, 70.18222382,
        68.09205923, 65.0538885, 65.55625907, 65.23775798, 64.16328749, 62.37497178, 63.36721165, 64.27943319, 67.5582113, 68.85053734,
        68.9018148,  # Red meat consumption data for the United States
    ]
}

df = pd.DataFrame(data)

# %%
# Create a line chart for red meat consumption over time
plt.figure(figsize=(10, 6))

# %%
# Line chart for red meat consumption
for country, color in zip(['Hong Kong', 'India', 'United States'], ['blue', 'green', 'red']):
    country_data = df[df['Country'] == country]
    plt.plot(country_data['Year'], country_data['Total Red meat consumed in kgs per capita'], label=country, color=color)

plt.title("Red Meat Consumption Over Time")
plt.xlabel("Year")
plt.ylabel("Red Meat Consumption (kgs per capita)")
plt.legend()

plt.tight_layout()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create a DataFrame with the provided data
data = {
    'Year': [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020] * 3,
    'Country': ['Hong Kong'] * 21 + ['India'] * 21 + ['United States'] * 21,
    'Life expectancy at birth': [
        80.7, 81.1, 81.3, 81.2, 81.4, 81.8, 82.0, 82.2, 82.4, 82.6, 83.0, 83.2, 83.6, 83.8, 84.1, 84.3, 84.5, 84.9, 85.2, 85.3, 85.2,
        62.7, 63.1, 63.6, 64.1, 64.5, 65.0, 65.4, 65.8, 66.1, 66.5, 66.9, 67.4, 67.9, 68.5, 69.1, 69.6, None, None, None, None, 70.1,
        76.8, 76.9, 77.0, 77.2, 77.6, 77.6, 77.8, 78.1, 78.2, 78.6, 78.8, 78.8, 78.9, 79.0, 79.0, 78.9, 78.8, None, None, None, 77.4
    ]
}

df = pd.DataFrame(data)

# %%
# Filter data for the years 2000-2020
df_filtered = df[df['Year'].between(2000, 2020)]

# %%
# Create line chart for life expectancy
plt.figure(figsize=(12, 6))

for country in ['Hong Kong', 'India', 'United States']:
    country_data = df_filtered[df_filtered['Country'] == country]
    plt.plot(country_data['Year'], country_data['Life expectancy at birth'], label=country)

plt.title("Life Expectancy Over the Years 2000-2020")
plt.xlabel("Year")
plt.ylabel("Life Expectancy at Birth")
plt.legend()
plt.grid(True)

plt.show()

# %%
# Create a DataFrame with the provided data
data = {
    'Year': [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020] * 3,
    'Country': ['Hong Kong'] * 21 + ['India'] * 21 + ['United States'] * 21,
    'Life Expectancy': [
        80.7, 81.1, 81.3, 81.2, 81.4, 81.8, 82.0, 82.2, 82.4, 82.6, 83.0, 83.2, 83.6, 83.8, 84.1, 84.3, 84.5, 84.9, 85.2, 85.3, 85.2,
        62.7, 63.1, 63.6, 64.1, 64.5, 65.0, 65.4, 65.8, 66.1, 66.5, 66.9, 67.4, 67.9, 68.5, 69.1, 69.6, 70.1, 70.5, 70.7, 70.9, 70.1,
        76.8, 76.9, 77.0, 77.2, 77.6, 77.6, 77.8, 78.1, 78.2, 78.6, 78.8, 78.8, 78.9, 79.0, 79.0, 78.9, 78.8, 78.8, 79.0, 79.1, 77.4,
    ],
    'Red Meat Consumption (kg per capita)': [
        70.14531433, 70.8399659, 68.56647245, 72.3551376, 79.0422852, 77.8897127, 83.1730689, 82.2914734, 83.7957905, 85.4121947, 66.9894391, 68.0644875, 77.0838158, 73.4274147, 74.4634309, 77.2608296, 80.9551505, 83.0424437, 81.7943729, 75.39197774, 80.7471877,
        3.05901455, 3.06369999, 2.96058761, 2.88762105, 2.90298509, 2.7821347, 2.73053629, 2.73773172, 2.7061126, 2.58717161, 2.33800452, 2.047988, 1.83736102, 1.63684983, 1.7542318, 1.8322195, 1.77112029, 1.70028898, 1.9069346, 1.87706668, 1.95677027,
        74.8776286, 73.73893517, 75.57986215, 73.9678193, 74.28694286, 73.00401356, 72.85807895, 73.0509517, 71.2234512, 70.18222382, 68.09205923, 65.0538885, 65.55625907, 65.23775798, 64.16328749, 62.37497178, 63.36721165, 64.27943319, 67.5582113, 68.85053734, 68.9018148,
    ]
}

df = pd.DataFrame(data)

# %%
# Filter data for the specified countries
countries = ['Hong Kong', 'India', 'United States']
df_filtered = df[df['Country'].isin(countries)]

# %%
# Define line colors
colors = {'Hong Kong': 'lightblue', 'India': 'orange', 'United States': 'green'}

for country in countries:
    country_data = df_filtered[df_filtered['Country'] == country]
    plt.plot(country_data['Year'], country_data['Life Expectancy'], label=f'{country} - Life Expectancy', color=colors[country])
    plt.plot(country_data['Year'], country_data['Red Meat Consumption (kg per capita)'], label=f'{country} - Red Meat', linestyle='--', color=colors[country])

plt.title("Life Expectancy and Red Meat Consumption Over the Years")
plt.xlabel("Year")
plt.ylabel("Value")
plt.legend()
plt.grid(True)

plt.show()

# %%
# Create a DataFrame with the provided data
data = {
    'Year': [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020] * 3,
    'Country': ['Hong Kong'] * 21 + ['India'] * 21 + ['United States'] * 21,
    'Vegetable Oil Consumption (kg per capita)': [
        15.42, 17.33, 16.27, 15.48, 15.68, 15.12, 14.78, 12.71, 11.31, 10.8, 10.5, 10.4, 10.6, 10.5, None, None, None, None, None, None, None,
        8.1, 7.4, 7.9, 7.6, 7.9, 8.5, 8.8, 8.8, 8.3, 9.2, 8.6, 8.8, 8.9, 8.8, None, None, None, None, None, None, 9.6,
        27.6, 26, 26.9, 26.6, 27.2, 28, 27.5, 27.9, 28.3, 29.6, 29.5, 30.6, 29.9, 30, None, None, None, None, None, None, None,
    ]
}

df = pd.DataFrame(data)

# %%
# Filter data for the specified countries
countries = ['Hong Kong', 'India', 'United States']
df_filtered = df[df['Country'].isin(countries)]

# %%
# Create line chart for vegetable oil consumption
plt.figure(figsize=(12, 6))

# %%
# Define line colors
colors = {'Hong Kong': 'lightblue', 'India': 'orange', 'United States': 'green'}

for country in countries:
    country_data = df_filtered[df_filtered['Country'] == country]
    plt.plot(country_data['Year'], country_data['Vegetable Oil Consumption (kg per capita)'], label=f'{country}', color=colors[country])

plt.title("Vegetable Oil Consumption per Capita (2000-2020)")
plt.xlabel("Year")
plt.ylabel("Consumption (kg per capita)")
plt.legend()
plt.grid(True)

plt.show()

# %%
# Create a DataFrame with the provided data
data = {
    'Year': [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020] * 3,
    'Country': ['Hong Kong'] * 21 + ['India'] * 21 + ['United States'] * 21,
    'Vegetable Oil Consumption (kg per capita)': [
        15.42, 17.33, 16.27, 15.48, 15.68, 15.12, 14.78, 12.71, 11.31, 10.8, 10.5, 10.4, 10.6, 10.5, None, None, None, None, None, None, None,
        8.1, 7.4, 7.9, 7.6, 7.9, 8.5, 8.8, 8.8, 8.3, 9.2, 8.6, 8.8, 8.9, 8.8, None, None, None, None, None, None, 9.6,
        27.6, 26, 26.9, 26.6, 27.2, 28, 27.5, 27.9, 28.3, 29.6, 29.5, 30.6, 29.9, 30, None, None, None, None, None, None, None,
    ]
}

df = pd.DataFrame(data)

# %%
# Filter data for the specified countries
countries = ['Hong Kong', 'India', 'United States']
df_filtered = df[df['Country'].isin(countries)]

# %%
# Create line chart for vegetable oil consumption
plt.figure(figsize=(12, 6))

# %%
# Define line colors
colors = {'Hong Kong': 'lightblue', 'India': 'orange', 'United States': 'green'}

for country in countries:
    country_data = df_filtered[df_filtered['Country'] == country]
    plt.plot(country_data['Year'], country_data['Vegetable Oil Consumption (kg per capita)'], label=f'{country}', color=colors[country])

plt.title("Vegetable Oil Consumption per Capita (2000-2020)")
plt.xlabel("Year")
plt.ylabel("Consumption (kg per capita)")
plt.legend()
plt.grid(True)

plt.show()

# %%
# Create a DataFrame with the provided data
data = {
    'Year': [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020] * 3,
    'Country': ['Hong Kong'] * 21 + ['India'] * 21 + ['United States'] * 21,
    'Diabetes Prevalence (%)': [
        1.5, 2.1, 2.6, 3.1, 3.9, 4.3, 4.8, 5.2, 5.5, 5.9, 6.3, 6.7, 7.1, 7.4, 5.1, 8.0, 8.4, 8.6, 6.2, 9.5, 9.8,
        7.3, 7.5, 7.6, 7.8, 7.9, 8.0, 8.1, 8.2, 8.3, 8.4, 8.4, 8.5, 8.6, 8.6, 8.7, 8.7, 8.7, 8.7, 8.7, 8.7, 9.6,
        6.3, 6.4, 6.5, 6.6, 6.7, 6.7, 6.8, 6.9, 6.9, 7.0, 7.0, 7.1, 7.1, 7.2, 7.3, 7.3, 7.3, 7.3, 7.3, 7.3, 10.0,
    ]
}

df = pd.DataFrame(data)

# %%
# Filter data for the specified countries
countries = ['Hong Kong', 'India', 'United States']
df_filtered = df[df['Country'].isin(countries)]

# %%
# Create bar chart for diabetes prevalence
plt.figure(figsize=(12, 6))

# %%
# Define bar colors
colors = {'Hong Kong': 'lightblue', 'India': 'orange', 'United States': 'green'}

# %%
# Group data by country and calculate the average diabetes prevalence for each country
avg_diabetes_prevalence = df_filtered.groupby('Country')['Diabetes Prevalence (%)'].mean()

# %%
# Plot the bar chart
avg_diabetes_prevalence.plot(kind='bar', color=[colors[country] for country in avg_diabetes_prevalence.index])
plt.title("Average Diabetes Prevalence by Country")
plt.xlabel("Country")
plt.ylabel("Average Diabetes Prevalence (%)")
plt.xticks(rotation=0)
plt.grid(axis='y')

plt.show()

# %%
# Create a DataFrame with the provided data
data = {
    'Year': [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020] * 3,
    'Country': ['Hong Kong'] * 21 + ['India'] * 21 + ['United States'] * 21,
    'Diabetes Prevalence (%)': [
        1.5, 2.1, 2.6, 3.1, 3.9, 4.3, 4.8, 5.2, 5.5, 5.9, 6.3, 6.7, 7.1, 7.4, 5.1, 8.0, 8.4, 8.6, 6.2, 9.5, 9.8,
        7.3, 7.5, 7.6, 7.8, 7.9, 8.0, 8.1, 8.2, 8.3, 8.4, 8.4, 8.5, 8.6, 8.6, 8.7, 8.7, 8.7, 8.7, 8.7, 8.7, 9.6,
        6.3, 6.4, 6.5, 6.6, 6.7, 6.7, 6.8, 6.9, 6.9, 7.0, 7.0, 7.1, 7.1, 7.2, 7.3, 7.3, 7.3, 7.3, 7.3, 7.3, 10.0,
    ]
}

df = pd.DataFrame(data)

# %%
# Filter data for the specified countries
countries = ['Hong Kong', 'India', 'United States']
df_filtered = df[df['Country'].isin(countries)]

# %%
# Create a line chart for diabetes prevalence
plt.figure(figsize=(12, 6))

# %%
# Define line colors
colors = {'Hong Kong': 'lightblue', 'India': 'orange', 'United States': 'green'}

# %%
# Plot the lines for each country
for country in countries:
    country_data = df_filtered[df_filtered['Country'] == country]
    plt.plot(country_data['Year'], country_data['Diabetes Prevalence (%)'], label=country, color=colors[country])

plt.title("Diabetes Prevalence Over the Years")
plt.xlabel("Year")
plt.ylabel("Diabetes Prevalence (%)")
plt.legend()
plt.grid()

plt.show()

# %%
# Sample data
data = {
    'Year': [
        2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010,
        2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020
    ],
    'Red meat consumption (kgs per capita)': [
        70.14531433, 70.8399659, 68.56647245, 72.3551376, 79.0422852, 77.8897127,
        83.1730689, 82.2914734, 83.7957905, 85.4121947, 66.9894391, 68.0644875,
        77.0838158, 73.4274147, 74.4634309, 77.2608296, 80.9551505, 83.0424437,
        81.7943729, 75.39197774, 80.7471877,
    ],
    'Diabetes prevalence (%)': [
        1.5, 2.1, 2.6, 3.1, 3.9, 4.3, 4.8, 5.2, 5.5, 5.9, 6.3, 6.7, 7.1, 7.4,
        5.1, 8.0, 8.4, 8.6, 6.2, 9.5, 9.8,
    ]
}

# Create a DataFrame
df = pd.DataFrame(data)

# %%
# Plotting the line chart
plt.figure(figsize=(10, 6))
plt.plot(df['Year'], df['Red meat consumption (kgs per capita)'], label='Red meat consumption', marker='o')
plt.plot(df['Year'], df['Diabetes prevalence (%)'], label='Diabetes prevalence', marker='o')

plt.title('Red Meat Consumption and Diabetes Prevalence Over the Years')
plt.xlabel('Year')
plt.ylabel('Value')
plt.legend()
plt.grid(True)

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Sample data
data = {
    'Year': [
        2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010,
        2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020,
        2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010,
        2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020,
        2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010,
        2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020
    ],
    'Country': [
        'Hong Kong', 'Hong Kong', 'Hong Kong', 'Hong Kong', 'Hong Kong', 'Hong Kong',
        'Hong Kong', 'Hong Kong', 'Hong Kong', 'Hong Kong', 'Hong Kong', 'Hong Kong',
        'Hong Kong', 'Hong Kong', 'Hong Kong', 'Hong Kong', 'Hong Kong', 'Hong Kong',
        'Hong Kong', 'Hong Kong', 'Hong Kong',
        'India', 'India', 'India', 'India', 'India', 'India', 'India', 'India', 'India',
        'India', 'India', 'India', 'India', 'India', 'India', 'India', 'India', 'India',
        'India', 'India', 'India',
        'United States', 'United States', 'United States', 'United States', 'United States',
        'United States', 'United States', 'United States', 'United States', 'United States',
        'United States', 'United States', 'United States', 'United States', 'United States',
        'United States', 'United States', 'United States', 'United States', 'United States',
        'United States'
    ],
    'Total Red meat consumed in kgs per capita': [
        70.14531433, 70.8399659, 68.56647245, 72.3551376, 79.0422852, 77.8897127,
        83.1730689, 82.2914734, 83.7957905, 85.4121947, 66.9894391, 68.0644875,
        77.0838158, 73.4274147, 74.4634309, 77.2608296, 80.9551505, 83.0424437,
        81.7943729, 75.39197774, 80.7471877,
        3.05901455, 3.06369999, 2.96058761, 2.88762105, 2.90298509, 2.7821347,
        2.73053629, 2.73773172, 2.7061126, 2.58717161, 2.33800452, 2.047988,
        1.83736102, 1.63684983, 1.7542318, 1.8322195, 1.77112029, 1.70028898,
        1.9069346, 1.87706668, 1.95677027,
        74.8776286, 73.73893517, 75.57986215, 73.9678193, 74.28694286, 73.00401356,
        72.85807895, 73.0509517, 71.2234512, 70.18222382, 68.09205923, 65.0538885,
        65.55625907, 65.23775798, 64.16328749, 62.37497178, 63.36721165, 64.27943319,
        67.5582113, 68.85053734, 68.9018148
    ],
    'Life expectancy at birth': [
        80.7, 81.1, 81.3, 81.2, 81.4, 81.8, 82, 82.2, 82.4, 82.6, 83, 83.2,
        83.6, 83.8, 84.1, 84.3, 84.5, 84.9, 85.2, 85.3, 85.2,
        62.7, 63.1, 63.6, 64.1, 64.5, 65, 65.4, 65.8, 66.1, 66.5, 66.9, 67.4,
        67.9, 68.5, 69.1, 69.6, 70.1, None, None, None, None,
        76.8, 76.9, 77, 77.2, 77.6, 77.6, 77.8, 78.1, 78.2, 78.6, 78.8, 78.8,
        78.9, 79, 79, None, 78.9, None, None, 77.4, None
    ],
    'Vegetable oil consumption per capita (Unit: kg)': [
        15.42, 17.33, 16.27, 15.48, 15.68, 15.12, 14.78, 12.71, 11.31, 10.8, 10.5, 10.4,
        10.6, 10.5, None, None, None, None, None, None, None,
        8.1, 7.4, 7.9, 7.6, 7.9, 8.5, 8.8, 8.8, 8.3, 9.2, 8.6, 8.8, 8.9, 8.8, None, None,
        None, None, None, None, None,
        27.6, 26, 26.9, 26.6, 27.2, 28, 27.5, 27.9, 28.3, 29.6, 29.5, 30.6, 29.9, 30,
        30, None, 78.9, None, None, None, None
    ],
    'Diabetes prevalence (%)': [
        1.5, 2.1, 2.6, 3.1, 3.9, 4.3, 4.8, 5.2, 5.5, 5.9, 6.3, 6.7,
        7.1, 7.4, 5.1, 8, 8.4, 8.6, 6.2, 9.5, 9.8,
        7.3, 7.5, 7.6, 7.8, 7.9, 8, 8.1, 8.2, 8.3, 8.4, 8.4, 8.5,
        8.6, 8.6, 8.7, 8.7, None, None, None, None, None,
        6.3, 6.4, 6.5, 6.6, 6.7, 6.7, 6.8, 6.9, 6.9, 7, 7, 7.1,
        7.1, 7.2, 7.3, 7.6, None, 7.8, None, None, 10
    ]
}

# Create a DataFrame
df = pd.DataFrame(data)

# %%
# Generate a correlation matrix
correlation_matrix = df.corr()
# Out:
# <ipython-input-33-b7b7037646c7>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()

# %%
# Create a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()
